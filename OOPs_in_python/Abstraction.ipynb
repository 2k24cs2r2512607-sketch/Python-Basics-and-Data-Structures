# %%
from abc import ABC,abstractmethod

# %%
class Bank(ABC):
    def bank(self):
        pass
    @abstractmethod
    def security(self):
        pass

# %%
class webapp(Bank):
    def print_method(self):
        pass
    def security(self):
        print("abstractmethod")

# %%
w=webapp()
